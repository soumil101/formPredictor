# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Shooting Form Data/path_detail.csv')

# %%
df.head()
# Out:
#       pid    fnm     lnm  hght      t  ddst        cx        cy        cz  \
# 0  201935  James  Harden  77.0  0.000  25.0 -0.114509  0.168085  3.347305
# 1  201935  James  Harden  77.0  0.001  25.0 -0.122287  0.164799  3.353028
# 2  201935  James  Harden  77.0  0.002  25.0 -0.130059  0.161515  3.358850
# 3  201935  James  Harden  77.0  0.003  25.0 -0.137822  0.158233  3.364775
# 4  201935  James  Harden  77.0  0.004  25.0 -0.145574  0.154954  3.370802
#
#         cvx  ...         cv        cax       cay         caz          ca  \
# 0 -7.779792  ...  10.145788  -0.697121  0.080510   98.930052   98.932541
# 1 -7.777437  ...  10.199382   2.354344  0.806486   99.811613   99.842633
# 2 -7.772032  ...  10.251623   5.405808  1.532461  100.693173  100.849821
# 3 -7.763574  ...  10.302562   8.457273  2.258436  101.574734  101.951226
# 4 -7.752066  ...  10.352252  11.508738  2.984411  102.456294  103.143831
#
#       rt        dx        dy        dz         d
# ...

# %%
df_james = df[df['pid'] == 201935]

# %%
df_james.tail()
# Out:
#         pid    fnm     lnm  hght      t  ddst        cx        cy        cz  \
# 375  201935  James  Harden  77.0  0.375  25.0  0.025176  0.012966  8.219076
# 376  201935  James  Harden  77.0  0.376  25.0  0.018106  0.012515  8.231352
# 377  201935  James  Harden  77.0  0.377  25.0  0.010959  0.012066  8.243658
# 378  201935  James  Harden  77.0  0.378  25.0  0.003735  0.011617  8.255994
# 379  201935  James  Harden  77.0  0.379  25.0 -0.003567  0.011170  8.268362
#
#           cvx  ...         cv        cax       cay        caz         ca  \
# 375 -6.994046  ...  14.110512 -75.848830  0.824565  28.326373  80.969799
# 376 -7.070305  ...  14.173620 -76.258825  0.994167  29.088031  81.624201
# 377 -7.146974  ...  14.237775 -76.668820  1.163768  29.849688  82.282842
# 378 -7.224053  ...  14.302974 -77.078814  1.333370  30.611346  82.945621
# 379 -7.301541  ...  14.369215 -77.488809  1.502971  31.373003  83.612438
#
#         rt        dx        dy        dz         d
# ...

# %%
plt.figure(figsize=(5, 7))  # Set the figure size (width, height) in inches
plt.scatter(df_james['cy'], df_james.index)
plt.ylabel('Index')
plt.xlabel('cx')
plt.title('Scatter Plot of cy')
plt.show()
